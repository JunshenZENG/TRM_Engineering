# %%
from VaR.data_processing.excel_input_data_processor import VaRExcelReader
from datetime import date
from VaR.Engine.shift_calculation import AbsoluteShiftCalculation, RelativeShiftCalculation, LogarithmicShiftCalculation

# %%
data_asset = VaRExcelReader(input_folder="input", file_name="var_input_data.xlsx")
data_dict = data_asset.get_var_calculation_input(valuation_date=date(2019, 11, 15), portfolio_name="FXTEST")

# %%
shift_market = LogarithmicShiftCalculation(data_dict)

# %%
shift_market.get_shifted_market_rates_matrix()
# Out:
# array([[ 2.11264807e-03,  2.52352099e-03],
#        [-4.66401595e-05,  9.72289819e-04],
#        [-7.46538546e-04,  6.73581098e-03],
#        [ 5.30696619e-03, -1.36221326e-04],
#        [ 1.16071895e-05,  1.58311405e-03],
#        [-1.51006545e-03, -1.57853229e-03],
#        [ 3.83540314e-04,  1.09646729e-03],
#        [ 3.42209847e-03, -5.58255477e-03],
#        [-8.92096892e-04, -3.52702587e-04],
#        [-1.64725572e-03, -4.28644683e-03],
#        [ 3.45379449e-03, -1.28509091e-03],
#        [-3.17519445e-03,  9.70795728e-03],
#        [ 1.29910821e-03, -1.75808765e-03],
#        [ 1.50578016e-03, -1.67305107e-03],
#        [ 2.54600163e-04,  4.40548049e-04],
#        [-1.41269130e-03, -8.37207302e-04],
#        [-4.52019317e-04,  3.60820597e-03],
#        [-4.83429566e-03,  6.58631388e-04],
#        [ 6.03922675e-03, -1.49352103e-03],
#        [ 2.42861723e-03, -4.53815244e-03],
#        [-2.89188046e-03,  3.96651027e-03],
#        [ 5.09577756e-04, -1.84908039e-03],
# ...
